# %%
import numpy as np
import matplotlib.pyplot as plt
from pymatreader import read_mat
from scipy import signal
from lsfr import *

# %%
prn= np.array(PRN(10))

prn_p = np.repeat(prn, 3)
print(prn_p.shape)
prn_e = np.append(prn_p[1::], prn_p[0])
print(prn_e.shape)
prn_l = np.insert(prn_p[0:len(prn_p)-1], 0, prn_p[1023])
print(prn_l.shape)


mm  = prn_p * prn_p

plt.plot(mm)
plt.show()

mk = prn_l[::-1] * np.repeat(np.array(PRN(1)), 3)
plt.plot(mk)    
plt.show()
# Out:
# (3069,)
# (3069,)
# (3069,)
